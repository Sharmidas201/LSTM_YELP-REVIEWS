# %% [markdown]
# **SHARMI DAS.   N01639206**

# %% [markdown]
# **FINAL OUTCOME FROM THIS NOTEBOOK**
#
# **Best Hyperparameters: {'lr': 0.001, 'wd': 1e-06, 'dropout': 0.3}**
#
# **Best Validation Accuracy: 84.52667124542124**

# %% [markdown]
# # LSTM Sentiment Analysis Model Definition
#
# This code defines an LSTM (Long Short-Term Memory) neural network model using PyTorch for sentiment analysis. It includes an embedding layer, LSTM layers, and a fully connected output layer. The model computes the forward pass and calculates the loss using binary cross-entropy with logits. It also incorporates dropout for regularization during training.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import torch.distributed as dist

import time
import os
import sys
import io

class LSTM_model(nn.Module):
    def __init__(self,vocab_size,n_hidden):
        super(LSTM_model, self).__init__()

        self.embedding = nn.Embedding(vocab_size,n_hidden)#,padding_idx=0)

        #self.lstm = nn.LSTM(n_hidden,n_hidden)
        self.lstm = nn.LSTM(n_hidden,n_hidden,num_layers=2,dropout=0.4)
        self.fc_output = nn.Linear(n_hidden, 1)

        #self.loss = nn.CrossEntropyLoss()
        self.loss = nn.BCEWithLogitsLoss()

    def forward(self, X, t, train=True):

        embed = self.embedding(X) # batch_size, time_steps, features
        no_of_timesteps = embed.shape[1]
        n_hidden = embed.shape[2]
        input = embed.permute(1, 0, 2) # input : [len_seq, batch_size, embedding_dim]
        hidden_state = Variable(torch.zeros(2*1, len(X), n_hidden)).cuda() # [num_layers(=2) * num_directions(=1), batch_size, n_hidden]
        cell_state = Variable(torch.zeros(2*1, len(X), n_hidden)).cuda() # [num_layers(=2) * num_directions(=1), batch_size, n_hidden]
        # final_hidden_state, final_cell_state : [num_layers(=2) * num_directions(=1), batch_size, n_hidden]
        output, (final_hidden_state, final_cell_state) = self.lstm(input, (hidden_state, cell_state))
        #output = output.permute(1, 2, 0) # output : [batch_size, n_hidden, len_seq]
        h = output[-1]
        #pool = nn.MaxPool1d(no_of_timesteps)
        #h = pool(output)
        h = h.view(h.size(0),-1)
        h = self.fc_output(h)
        return self.loss(h[:,0],t), h[:,0]#F.softmax(h, dim=1)

# %% [markdown]
# # Data Preprocessing for Sentiment Analysis
#
# This code segment preprocesses the data for sentiment analysis. It reads training and testing data from CSV files using pandas, splits the data into features (x) and labels (y), and further splits it into training, validation, and testing sets using scikit-learn's train_test_split function. It saves the preprocessed data as numpy arrays for future use.

# %%
import pandas as pd
import numpy as np
import os
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# Read train and test data from CSV files
train_df = pd.read_csv('/content/sample_data/training_data (1).csv')
test_df = pd.read_csv('/content/sample_data/testing_data.csv')

# Assuming 'x' columns contain features and 'y' columns contain labels
x_data = train_df['Reviews'].values
y_data = train_df['Sentiment'].values

# Split data into training, validation, and testing sets
x_train_all, x_test, y_train_all, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=SEED)
x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.2, random_state=SEED)

# Create the 'preprocessed_data' directory if it doesn't exist
directory = '../preprocessed_data/'
if not os.path.exists(directory):
    os.makedirs(directory)

# Save train and test data as numpy arrays
np.save(directory + 'x_train.npy', x_train)
np.save(directory + 'y_train.npy', y_train)
np.save(directory + 'x_test.npy', x_test)
np.save(directory + 'y_test.npy', y_test)

# %%
# Load train and test data as numpy arrays
x_train = np.load('../preprocessed_data/x_train.npy', allow_pickle=True)
y_train = np.load('../preprocessed_data/y_train.npy')
x_test = np.load('../preprocessed_data/x_test.npy', allow_pickle=True)
y_test = np.load('../preprocessed_data/y_test.npy')

# Tokenization and Padding
vocab_size = 8000
sequence_len = 150
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(x_train)

x_train_seq = tokenizer.texts_to_sequences(x_train)
x_train_pad = pad_sequences(x_train_seq, maxlen=sequence_len, padding='post')

x_test_seq = tokenizer.texts_to_sequences(x_test)
x_test_pad = pad_sequences(x_test_seq, maxlen=sequence_len, padding='post')

# Convert to numpy arrays
x_train_pad = np.array(x_train_pad)
x_test_pad = np.array(x_test_pad)

vocab_size += 1  # Increment vocab size for padding token

# Preprocess validation set
x_val = x_val.astype(str)

x_val_seq = tokenizer.texts_to_sequences(x_val)
x_val_pad = pad_sequences(x_val_seq, maxlen=sequence_len, padding='post')
x_val_pad = np.array(x_val_pad)

# %% [markdown]
# ##Before hyperparameter tuning , with Learning Rate Scheduler

# %% [markdown]
# This code segment trains an LSTM model for sentiment analysis using PyTorch. It begins by initializing the model with a vocabulary size and hidden dimension of 800. The Adam optimizer is utilized with a learning rate of 0.001. Additionally, a learning rate scheduler is defined to adjust the learning rate based on validation loss. The model is trained for 5 epochs, with training and validation loss and accuracy monitored. After training, the model is evaluated on the test data, and metrics such as accuracy, loss, precision, recall, and F1 score are computed and printed. Overall, **the model achieves a testing accuracy of 85.09% with a precision of 0.8974, recall of 0.8380, and F1 score of 0.8667.**

# %%
model = LSTM_model(vocab_size, 800)
model.cuda()

# Define optimizer
LR = 0.001
optimizer = optim.Adam(model.parameters(), lr=LR)

# Define learning rate scheduler
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.1, verbose=True)

batch_size = 200
no_of_epochs = 5
L_Y_train = len(y_train)
L_Y_val = len(y_val)
L_Y_test = len(y_test)

model.train()

train_loss = []
val_loss = []
train_accu = []
val_accu = []

prev_val_loss = float('inf')
patience = 2  # Number of epochs to wait before stopping if the model stops learning
no_improvement_counter = 0

for epoch in range(no_of_epochs):
    # Training
    model.train()

    epoch_acc = 0.0
    epoch_loss = 0.0
    epoch_counter = 0

    time1 = time.time()

    I_permutation = np.random.permutation(L_Y_train)

    for i in range(0, L_Y_train, batch_size):

        x_input = x_train_pad[I_permutation[i:i+batch_size]]
        y_input = np.asarray(y_train[I_permutation[i:i+batch_size]], dtype=float)
        data = Variable(torch.LongTensor(x_input)).cuda()
        target = Variable(torch.FloatTensor(y_input)).cuda()

        optimizer.zero_grad()
        loss, pred = model(data, target)
        loss.backward()

        optimizer.step()   # Update weights

        prediction = pred >= 0.0
        truth = target >= 0.5
        acc = prediction.eq(truth).sum().cpu().data.numpy()
        epoch_acc += acc
        epoch_loss += loss.data.item()
        epoch_counter += batch_size

    epoch_acc /= epoch_counter
    epoch_loss /= (epoch_counter / batch_size)

    train_loss.append(epoch_loss)
    train_accu.append(epoch_acc)

    print(f"Epoch {epoch}: - Training Accuracy: {epoch_acc * 100:.2f}% - Training Loss: {epoch_loss:.4f} - Time Taken: {time.time() - time1:.4f} seconds")
    # Validation
    model.eval()

    val_loss_epoch = 0.0
    val_acc_epoch = 0.0
    val_counter = 0

    for i in range(0, L_Y_val, batch_size):

        x_input = x_val_pad[i:i+batch_size]
        y_input = np.asarray(y_val[i:i+batch_size], dtype=float)
        target = Variable(torch.FloatTensor(y_input)).cuda()
        data = Variable(torch.LongTensor(x_input)).cuda()
        with torch.no_grad():
            loss, pred = model(data, target)

        prediction = pred >= 0.0
        truth = target >= 0.5
        acc = prediction.eq(truth).sum().cpu().data.numpy()
        val_acc_epoch += acc
        val_loss_epoch += loss.data.item()
        val_counter += batch_size

    val_acc_epoch /= val_counter
    val_loss_epoch /= (val_counter / batch_size)

    val_loss.append(val_loss_epoch)
    val_accu.append(val_acc_epoch)

    print(f"  - Validation Accuracy: {val_acc_epoch * 100:.2f}% - Validation Loss: {val_loss_epoch:.4f}")

    # Adjust learning rate based on validation loss
    scheduler.step(val_loss_epoch)

    # Check for early stopping
    if val_loss_epoch >= prev_val_loss:
        no_improvement_counter += 1
    else:
        no_improvement_counter = 0
    prev_val_loss = val_loss_epoch

    if no_improvement_counter >= patience:
        print("Early stopping: Validation loss has not decreased for", patience, "epochs.")
        break
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Testing
model.eval()

test_loss = 0.0
test_acc = 0.0
test_precision = 0.0
test_recall = 0.0
test_f1 = 0.0
test_counter = 0

predictions = []
true_labels = []

for i in range(0, L_Y_test, batch_size):

    x_input = x_test_pad[i:i+batch_size]
    y_input = np.asarray(y_test[i:i+batch_size], dtype=float)
    target = Variable(torch.FloatTensor(y_input)).cuda()
    data = Variable(torch.LongTensor(x_input)).cuda()
    with torch.no_grad():
        loss, pred = model(data, target)

    prediction = pred >= 0.0
    truth = target >= 0.5
    acc = prediction.eq(truth).sum().cpu().data.numpy()
    test_acc += acc
    test_loss += loss.data.item()
    test_counter += batch_size

    # Convert predictions and true labels to numpy arrays
    predictions.extend(prediction.cpu().numpy())
    true_labels.extend(truth.cpu().numpy())

test_acc /= test_counter
test_loss /= (test_counter / batch_size)

# Convert lists to numpy arrays
predictions = np.array(predictions)
true_labels = np.array(true_labels)

# Calculate additional evaluation metrics
test_precision = precision_score(true_labels, predictions)
test_recall = recall_score(true_labels, predictions)
test_f1 = f1_score(true_labels, predictions)

print(f"Testing Accuracy: {test_acc * 100:.2f}%")
print(f"Testing Loss: {test_loss:.4f}")
print(f"Precision: {test_precision:.4f}")
print(f"Recall: {test_recall:.4f}")
print(f"F1 Score: {test_f1:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Epoch 0: - Training Accuracy: 54.23% - Training Loss: 0.6822 - Time Taken: 82.8267 seconds
#   - Validation Accuracy: 51.50% - Validation Loss: 0.6707
# Epoch 1: - Training Accuracy: 61.07% - Training Loss: 0.6535 - Time Taken: 82.0316 seconds
#   - Validation Accuracy: 58.84% - Validation Loss: 0.6796
# Epoch 2: - Training Accuracy: 67.42% - Training Loss: 0.5978 - Time Taken: 82.1675 seconds
#   - Validation Accuracy: 79.80% - Validation Loss: 0.4682
# Epoch 3: - Training Accuracy: 84.05% - Training Loss: 0.3726 - Time Taken: 82.5664 seconds
#   - Validation Accuracy: 80.70% - Validation Loss: 0.4327
# Epoch 4: - Training Accuracy: 89.24% - Training Loss: 0.2624 - Time Taken: 82.6324 seconds
#   - Validation Accuracy: 86.96% - Validation Loss: 0.3053
# Testing Accuracy: 85.09%
# Testing Loss: 0.2893
# Precision: 0.8974
# Recall: 0.8380
# F1 Score: 0.8667

# %% [markdown]
# ##Hyperparameter tuning and kfold crossvalidation

# %% [markdown]
# This code snippet implements hyperparameter tuning using k-fold cross-validation for a neural network model, particularly an LSTM-based one. It explores various combinations of learning rates, weight decays, and dropout probabilities to find the optimal configuration. During each iteration, it trains the model on different folds of the training data and evaluates performance on the validation set. It employs techniques like early stopping and learning rate adjustment based on validation loss to prevent overfitting and improve convergence. Finally, it reports the best hyperparameters and the corresponding validation accuracy achieved. In this run, **the best configuration consists of a learning rate of 0.001, weight decay of 1e-06, and a dropout probability of 0.3, achieving a validation accuracy of 84.53%.**

# %%
from sklearn.model_selection import KFold
from tqdm import tqdm

# Define k-fold cross-validation
num_folds = 3
kf = KFold(n_splits=num_folds)

# Define hyperparameters to tune
learning_rates = [0.001, 0.0001]
weight_decays = [1e-4, 1e-5, 1e-6]
dropout_probs = [0.3, 0.5, 0.7]

best_accuracy = 0.0
best_hyperparameters = {}
n_hidden = 100

# Perform k-fold cross-validation for hyperparameter tuning
for lr in learning_rates:
    for wd in weight_decays:
        for dp in dropout_probs:
            print(f'Training with LR={lr}, WD={wd}, Dropout={dp}')

            fold_accuracies = []

            for fold, (train_indices, val_indices) in enumerate(kf.split(x_train)):
                print(f'Fold {fold + 1}/{num_folds}')

                # Split data into training and validation sets for this fold
                x_train_fold = x_train[train_indices]
                y_train_fold = y_train[train_indices]
                x_val_fold = x_train[val_indices]
                y_val_fold = y_train[val_indices]

                # Initialize the model
                model = LSTM_model(vocab_size, n_hidden)
                model.cuda()

                # Define optimizer
                optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)

                # Training loop
                for epoch in range(num_epochs):  # Loop over the dataset multiple times
                    model.train()

                    epoch_acc = 0.0
                    epoch_loss = 0.0
                    epoch_counter = 0

                    time1 = time.time()

                    I_permutation = np.random.permutation(L_Y_train)

                    for i in range(0, L_Y_train, batch_size):

                        x_input = x_train_pad[I_permutation[i:i+batch_size]]
                        y_input = np.asarray(y_train[I_permutation[i:i+batch_size]], dtype=float)
                        data = Variable(torch.LongTensor(x_input)).cuda()
                        target = Variable(torch.FloatTensor(y_input)).cuda()

                        optimizer.zero_grad()
                        loss, pred = model(data, target)
                        loss.backward()

                        optimizer.step()   # Update weights

                        prediction = pred >= 0.0
                        truth = target >= 0.5
                        acc = prediction.eq(truth).sum().cpu().data.numpy()
                        epoch_acc += acc
                        epoch_loss += loss.data.item()
                        epoch_counter += batch_size

                    epoch_acc /= epoch_counter
                    epoch_loss /= (epoch_counter / batch_size)

                    train_loss.append(epoch_loss)
                    train_accu.append(epoch_acc)

                    print(f"Epoch {epoch + 1}/{num_epochs}: - Training Accuracy: {epoch_acc * 100:.2f}% - Training Loss: {epoch_loss:.4f} - Time Taken: {time.time() - time1:.4f} seconds")

                    # Validation
                    model.eval()

                    val_loss_epoch = 0.0
                    val_acc_epoch = 0.0
                    val_counter = 0

                    for i in range(0, L_Y_val, batch_size):

                        x_input = x_val_pad[i:i+batch_size]
                        y_input = np.asarray(y_val[i:i+batch_size], dtype=float)
                        target = Variable(torch.FloatTensor(y_input)).cuda()
                        data = Variable(torch.LongTensor(x_input)).cuda()
                        with torch.no_grad():
                            loss, pred = model(data, target)

                        prediction = pred >= 0.0
                        truth = target >= 0.5
                        acc = prediction.eq(truth).sum().cpu().data.numpy()
                        val_acc_epoch += acc
                        val_loss_epoch += loss.data.item()
                        val_counter += batch_size

                    val_acc_epoch /= val_counter
                    val_loss_epoch /= (val_counter / batch_size)

                    val_loss.append(val_loss_epoch)
                    val_accu.append(val_acc_epoch)

                    print(f"  - Validation Accuracy: {val_acc_epoch * 100:.2f}% - Validation Loss: {val_loss_epoch:.4f}")

                    # Adjust learning rate based on validation loss
                    scheduler.step(val_loss_epoch)

                    # Check for early stopping
                    if val_loss_epoch >= prev_val_loss:
                        no_improvement_counter += 1
                    else:
                        no_improvement_counter = 0
                    prev_val_loss = val_loss_epoch

                    if no_improvement_counter >= patience:
                        print("Early stopping: Validation loss has not decreased for", patience, "epochs.")
                        break

                    # Calculate validation accuracy for this fold
                    fold_accuracy = val_acc_epoch * 100  # Calculate accuracy for this fold
                    fold_accuracies.append(fold_accuracy)

            # Calculate average validation accuracy across all folds
            avg_accuracy = np.mean(fold_accuracies)
            print(f'Average Validation Accuracy: {avg_accuracy}')

            # Update best hyperparameters if this combination is the best so far
            if avg_accuracy > best_accuracy:
                best_accuracy = avg_accuracy
                best_hyperparameters = {'lr': lr, 'wd': wd, 'dropout': dp}

print(f'Best Hyperparameters: {best_hyperparameters}')
print(f'Best Validation Accuracy: {best_accuracy}')
# Out:
# Training with LR=0.001, WD=0.0001, Dropout=0.3
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 54.26% - Training Loss: 0.6783 - Time Taken: 3.1895 seconds
#   - Validation Accuracy: 54.77% - Validation Loss: 0.6676
# Epoch 2/10: - Training Accuracy: 57.20% - Training Loss: 0.6626 - Time Taken: 3.0991 seconds
#   - Validation Accuracy: 58.31% - Validation Loss: 0.6707
# Epoch 3/10: - Training Accuracy: 67.25% - Training Loss: 0.5882 - Time Taken: 3.1174 seconds
#   - Validation Accuracy: 80.57% - Validation Loss: 0.4235
# Epoch 4/10: - Training Accuracy: 85.96% - Training Loss: 0.3377 - Time Taken: 3.2336 seconds
#   - Validation Accuracy: 88.70% - Validation Loss: 0.2830
# Epoch 5/10: - Training Accuracy: 90.93% - Training Loss: 0.2307 - Time Taken: 3.1390 seconds
#   - Validation Accuracy: 89.88% - Validation Loss: 0.2526
# Epoch 6/10: - Training Accuracy: 92.74% - Training Loss: 0.1894 - Time Taken: 3.1177 seconds
#   - Validation Accuracy: 90.38% - Validation Loss: 0.2436
# Epoch 7/10: - Training Accuracy: 94.30% - Training Loss: 0.1550 - Time Taken: 3.1187 seconds
#   - Validation Accuracy: 90.24% - Validation Loss: 0.2460
# Epoch 8/10: - Training Accuracy: 95.40% - Training Loss: 0.1304 - Time Taken: 3.1645 seconds
#   - Validation Accuracy: 89.38% - Validation Loss: 0.2746
# Epoch 9/10: - Training Accuracy: 95.96% - Training Loss: 0.1139 - Time Taken: 3.0537 seconds
#   - Validation Accuracy: 89.84% - Validation Loss: 0.2907
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 55.11% - Training Loss: 0.6782 - Time Taken: 3.0521 seconds
#   - Validation Accuracy: 63.20% - Validation Loss: 0.6618
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 54.69% - Training Loss: 0.6759 - Time Taken: 3.1203 seconds
#   - Validation Accuracy: 55.05% - Validation Loss: 0.6637
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 80.28094951923077
# Training with LR=0.001, WD=0.0001, Dropout=0.5
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 57.11% - Training Loss: 0.6708 - Time Taken: 3.0385 seconds
#   - Validation Accuracy: 67.95% - Validation Loss: 0.6278
# Epoch 2/10: - Training Accuracy: 55.51% - Training Loss: 0.6788 - Time Taken: 3.0230 seconds
#   - Validation Accuracy: 57.23% - Validation Loss: 0.6788
# Epoch 3/10: - Training Accuracy: 56.40% - Training Loss: 0.6778 - Time Taken: 3.0326 seconds
#   - Validation Accuracy: 57.17% - Validation Loss: 0.6758
# Epoch 4/10: - Training Accuracy: 57.92% - Training Loss: 0.6704 - Time Taken: 3.1731 seconds
#   - Validation Accuracy: 70.61% - Validation Loss: 0.5917
# Epoch 5/10: - Training Accuracy: 75.05% - Training Loss: 0.5089 - Time Taken: 3.0401 seconds
#   - Validation Accuracy: 87.08% - Validation Loss: 0.3274
# Epoch 6/10: - Training Accuracy: 89.10% - Training Loss: 0.2787 - Time Taken: 3.0310 seconds
#   - Validation Accuracy: 89.26% - Validation Loss: 0.2672
# Epoch 7/10: - Training Accuracy: 92.34% - Training Loss: 0.2052 - Time Taken: 3.0227 seconds
#   - Validation Accuracy: 89.92% - Validation Loss: 0.2532
# Epoch 8/10: - Training Accuracy: 93.90% - Training Loss: 0.1694 - Time Taken: 5.3004 seconds
#   - Validation Accuracy: 90.00% - Validation Loss: 0.2531
# Epoch 9/10: - Training Accuracy: 95.38% - Training Loss: 0.1376 - Time Taken: 3.0588 seconds
#   - Validation Accuracy: 89.12% - Validation Loss: 0.3075
# Epoch 10/10: - Training Accuracy: 95.87% - Training Loss: 0.1192 - Time Taken: 3.0208 seconds
#   - Validation Accuracy: 89.62% - Validation Loss: 0.2893
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 54.34% - Training Loss: 0.6754 - Time Taken: 3.1584 seconds
#   - Validation Accuracy: 65.56% - Validation Loss: 0.6271
# Epoch 2/10: - Training Accuracy: 61.89% - Training Loss: 0.6497 - Time Taken: 3.0267 seconds
#   - Validation Accuracy: 53.97% - Validation Loss: 0.6828
# Epoch 3/10: - Training Accuracy: 58.02% - Training Loss: 0.6711 - Time Taken: 3.0356 seconds
#   - Validation Accuracy: 61.72% - Validation Loss: 0.6605
# Epoch 4/10: - Training Accuracy: 66.01% - Training Loss: 0.6138 - Time Taken: 3.0556 seconds
#   - Validation Accuracy: 78.77% - Validation Loss: 0.4859
# Epoch 5/10: - Training Accuracy: 76.21% - Training Loss: 0.5060 - Time Taken: 3.1232 seconds
#   - Validation Accuracy: 83.75% - Validation Loss: 0.3938
# Epoch 6/10: - Training Accuracy: 78.11% - Training Loss: 0.4653 - Time Taken: 3.0508 seconds
#   - Validation Accuracy: 85.40% - Validation Loss: 0.3678
# Epoch 7/10: - Training Accuracy: 87.36% - Training Loss: 0.3177 - Time Taken: 3.0470 seconds
#   - Validation Accuracy: 88.04% - Validation Loss: 0.3130
# Epoch 8/10: - Training Accuracy: 90.03% - Training Loss: 0.2566 - Time Taken: 3.0882 seconds
#   - Validation Accuracy: 89.10% - Validation Loss: 0.2722
# Epoch 9/10: - Training Accuracy: 91.34% - Training Loss: 0.2271 - Time Taken: 3.0934 seconds
#   - Validation Accuracy: 88.72% - Validation Loss: 0.2803
# Epoch 10/10: - Training Accuracy: 91.87% - Training Loss: 0.2104 - Time Taken: 3.0350 seconds
#   - Validation Accuracy: 89.40% - Validation Loss: 0.2725
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 54.66% - Training Loss: 0.6805 - Time Taken: 3.0372 seconds
#   - Validation Accuracy: 54.65% - Validation Loss: 0.6756
# Epoch 2/10: - Training Accuracy: 56.05% - Training Loss: 0.6767 - Time Taken: 3.1596 seconds
#   - Validation Accuracy: 54.99% - Validation Loss: 0.6841
# Epoch 3/10: - Training Accuracy: 59.69% - Training Loss: 0.6633 - Time Taken: 3.0363 seconds
#   - Validation Accuracy: 67.65% - Validation Loss: 0.6102
# Epoch 4/10: - Training Accuracy: 82.37% - Training Loss: 0.3975 - Time Taken: 3.0385 seconds
#   - Validation Accuracy: 88.28% - Validation Loss: 0.3072
# Epoch 5/10: - Training Accuracy: 91.15% - Training Loss: 0.2264 - Time Taken: 3.0283 seconds
#   - Validation Accuracy: 89.44% - Validation Loss: 0.2719
# Epoch 6/10: - Training Accuracy: 93.33% - Training Loss: 0.1766 - Time Taken: 3.1626 seconds
#   - Validation Accuracy: 89.50% - Validation Loss: 0.2941
# Epoch 7/10: - Training Accuracy: 94.98% - Training Loss: 0.1368 - Time Taken: 3.0240 seconds
#   - Validation Accuracy: 89.60% - Validation Loss: 0.2624
# Epoch 8/10: - Training Accuracy: 96.31% - Training Loss: 0.1065 - Time Taken: 3.0242 seconds
#   - Validation Accuracy: 89.66% - Validation Loss: 0.2740
# Epoch 9/10: - Training Accuracy: 96.99% - Training Loss: 0.0891 - Time Taken: 3.0608 seconds
#   - Validation Accuracy: 89.38% - Validation Loss: 0.3740
# Epoch 10/10: - Training Accuracy: 97.39% - Training Loss: 0.0770 - Time Taken: 3.1069 seconds
#   - Validation Accuracy: 89.22% - Validation Loss: 0.4060
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 78.81299734748009
# Training with LR=0.001, WD=0.0001, Dropout=0.7
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 54.23% - Training Loss: 0.6766 - Time Taken: 3.0025 seconds
#   - Validation Accuracy: 55.63% - Validation Loss: 0.6610
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 53.52% - Training Loss: 0.6789 - Time Taken: 3.0150 seconds
#   - Validation Accuracy: 55.27% - Validation Loss: 0.6631
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 53.94% - Training Loss: 0.6791 - Time Taken: 3.0927 seconds
#   - Validation Accuracy: 54.85% - Validation Loss: 0.6699
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: nan
# Training with LR=0.001, WD=1e-05, Dropout=0.3
# Fold 1/3
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Epoch 1/10: - Training Accuracy: 54.43% - Training Loss: 0.6785 - Time Taken: 3.0697 seconds
#   - Validation Accuracy: 64.98% - Validation Loss: 0.6481
# Epoch 2/10: - Training Accuracy: 62.28% - Training Loss: 0.6483 - Time Taken: 3.0190 seconds
#   - Validation Accuracy: 67.19% - Validation Loss: 0.6196
# Epoch 3/10: - Training Accuracy: 66.54% - Training Loss: 0.6219 - Time Taken: 3.0372 seconds
#   - Validation Accuracy: 70.51% - Validation Loss: 0.5904
# Epoch 4/10: - Training Accuracy: 77.32% - Training Loss: 0.4949 - Time Taken: 3.1563 seconds
#   - Validation Accuracy: 67.89% - Validation Loss: 0.5836
# Epoch 5/10: - Training Accuracy: 85.72% - Training Loss: 0.3495 - Time Taken: 3.0299 seconds
#   - Validation Accuracy: 84.90% - Validation Loss: 0.3733
# Epoch 6/10: - Training Accuracy: 89.46% - Training Loss: 0.2728 - Time Taken: 3.0376 seconds
#   - Validation Accuracy: 86.90% - Validation Loss: 0.3027
# Epoch 7/10: - Training Accuracy: 91.91% - Training Loss: 0.2155 - Time Taken: 3.2330 seconds
#   - Validation Accuracy: 88.72% - Validation Loss: 0.2917
# Epoch 8/10: - Training Accuracy: 93.17% - Training Loss: 0.1871 - Time Taken: 3.1310 seconds
#   - Validation Accuracy: 88.06% - Validation Loss: 0.3114
# Epoch 9/10: - Training Accuracy: 93.97% - Training Loss: 0.1670 - Time Taken: 3.0195 seconds
#   - Validation Accuracy: 81.49% - Validation Loss: 0.5227
# Epoch 10/10: - Training Accuracy: 94.23% - Training Loss: 0.1584 - Time Taken: 3.0474 seconds
#   - Validation Accuracy: 89.02% - Validation Loss: 0.2850
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 58.34% - Training Loss: 0.6615 - Time Taken: 3.0893 seconds
#   - Validation Accuracy: 66.85% - Validation Loss: 0.6150
# Epoch 2/10: - Training Accuracy: 70.83% - Training Loss: 0.5707 - Time Taken: 3.0889 seconds
#   - Validation Accuracy: 69.49% - Validation Loss: 0.5749
# Epoch 3/10: - Training Accuracy: 70.70% - Training Loss: 0.5591 - Time Taken: 3.0393 seconds
#   - Validation Accuracy: 80.63% - Validation Loss: 0.4483
# Epoch 4/10: - Training Accuracy: 82.18% - Training Loss: 0.4076 - Time Taken: 3.0365 seconds
#   - Validation Accuracy: 84.48% - Validation Loss: 0.3745
# Epoch 5/10: - Training Accuracy: 86.70% - Training Loss: 0.3255 - Time Taken: 3.1566 seconds
#   - Validation Accuracy: 86.18% - Validation Loss: 0.3300
# Epoch 6/10: - Training Accuracy: 89.80% - Training Loss: 0.2592 - Time Taken: 3.0263 seconds
#   - Validation Accuracy: 88.66% - Validation Loss: 0.2869
# Epoch 7/10: - Training Accuracy: 91.65% - Training Loss: 0.2170 - Time Taken: 3.0477 seconds
#   - Validation Accuracy: 89.54% - Validation Loss: 0.2661
# Epoch 8/10: - Training Accuracy: 93.33% - Training Loss: 0.1781 - Time Taken: 3.0430 seconds
#   - Validation Accuracy: 89.64% - Validation Loss: 0.2602
# Epoch 9/10: - Training Accuracy: 94.26% - Training Loss: 0.1523 - Time Taken: 3.1680 seconds
#   - Validation Accuracy: 86.54% - Validation Loss: 0.3624
# Epoch 10/10: - Training Accuracy: 95.17% - Training Loss: 0.1325 - Time Taken: 3.0369 seconds
#   - Validation Accuracy: 90.18% - Validation Loss: 0.2884
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 54.06% - Training Loss: 0.6781 - Time Taken: 3.0196 seconds
#   - Validation Accuracy: 54.59% - Validation Loss: 0.6421
# Epoch 2/10: - Training Accuracy: 62.69% - Training Loss: 0.6398 - Time Taken: 3.0650 seconds
#   - Validation Accuracy: 65.08% - Validation Loss: 0.6068
# Epoch 3/10: - Training Accuracy: 78.90% - Training Loss: 0.4629 - Time Taken: 3.1140 seconds
#   - Validation Accuracy: 85.52% - Validation Loss: 0.3720
# Epoch 4/10: - Training Accuracy: 87.95% - Training Loss: 0.3015 - Time Taken: 3.0325 seconds
#   - Validation Accuracy: 88.74% - Validation Loss: 0.2799
# Epoch 5/10: - Training Accuracy: 91.46% - Training Loss: 0.2249 - Time Taken: 3.0448 seconds
#   - Validation Accuracy: 89.70% - Validation Loss: 0.2538
# Epoch 6/10: - Training Accuracy: 93.84% - Training Loss: 0.1693 - Time Taken: 3.1067 seconds
#   - Validation Accuracy: 89.84% - Validation Loss: 0.2510
# Epoch 7/10: - Training Accuracy: 94.76% - Training Loss: 0.1439 - Time Taken: 3.0593 seconds
#   - Validation Accuracy: 89.30% - Validation Loss: 0.2757
# Epoch 8/10: - Training Accuracy: 95.04% - Training Loss: 0.1368 - Time Taken: 3.0189 seconds
#   - Validation Accuracy: 90.16% - Validation Loss: 0.2900
# Epoch 9/10: - Training Accuracy: 96.77% - Training Loss: 0.0921 - Time Taken: 3.0330 seconds
#   - Validation Accuracy: 89.66% - Validation Loss: 0.3083
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 81.2428456959707
# Training with LR=0.001, WD=1e-05, Dropout=0.5
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 54.10% - Training Loss: 0.6785 - Time Taken: 3.1390 seconds
#   - Validation Accuracy: 58.63% - Validation Loss: 0.6560
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 57.92% - Training Loss: 0.6686 - Time Taken: 3.0179 seconds
#   - Validation Accuracy: 54.47% - Validation Loss: 0.6792
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 54.18% - Training Loss: 0.6773 - Time Taken: 3.0085 seconds
#   - Validation Accuracy: 55.49% - Validation Loss: 0.6762
# Epoch 2/10: - Training Accuracy: 56.00% - Training Loss: 0.6787 - Time Taken: 3.0321 seconds
#   - Validation Accuracy: 55.23% - Validation Loss: 0.6792
# Epoch 3/10: - Training Accuracy: 56.15% - Training Loss: 0.6784 - Time Taken: 3.1286 seconds
#   - Validation Accuracy: 57.65% - Validation Loss: 0.6748
# Epoch 4/10: - Training Accuracy: 58.09% - Training Loss: 0.6715 - Time Taken: 3.0336 seconds
#   - Validation Accuracy: 69.03% - Validation Loss: 0.6163
# Epoch 5/10: - Training Accuracy: 74.98% - Training Loss: 0.5165 - Time Taken: 3.0445 seconds
#   - Validation Accuracy: 85.28% - Validation Loss: 0.3503
# Epoch 6/10: - Training Accuracy: 89.13% - Training Loss: 0.2742 - Time Taken: 3.0822 seconds
#   - Validation Accuracy: 89.46% - Validation Loss: 0.2735
# Epoch 7/10: - Training Accuracy: 93.17% - Training Loss: 0.1888 - Time Taken: 3.2773 seconds
#   - Validation Accuracy: 89.34% - Validation Loss: 0.2684
# Epoch 8/10: - Training Accuracy: 94.95% - Training Loss: 0.1459 - Time Taken: 3.0352 seconds
#   - Validation Accuracy: 89.72% - Validation Loss: 0.2906
# Epoch 9/10: - Training Accuracy: 96.10% - Training Loss: 0.1112 - Time Taken: 3.0271 seconds
#   - Validation Accuracy: 89.94% - Validation Loss: 0.2733
# Epoch 10/10: - Training Accuracy: 97.39% - Training Loss: 0.0834 - Time Taken: 3.1610 seconds
#   - Validation Accuracy: 89.56% - Validation Loss: 0.3226
# Average Validation Accuracy: 77.0713141025641
# Training with LR=0.001, WD=1e-05, Dropout=0.7
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 59.19% - Training Loss: 0.6629 - Time Taken: 3.0252 seconds
#   - Validation Accuracy: 72.58% - Validation Loss: 0.5746
# Epoch 2/10: - Training Accuracy: 71.71% - Training Loss: 0.5615 - Time Taken: 3.0299 seconds
#   - Validation Accuracy: 64.24% - Validation Loss: 0.6615
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 54.44% - Training Loss: 0.6801 - Time Taken: 3.0152 seconds
#   - Validation Accuracy: 65.24% - Validation Loss: 0.6631
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 53.80% - Training Loss: 0.6796 - Time Taken: 3.1747 seconds
#   - Validation Accuracy: 61.74% - Validation Loss: 0.6425
# Epoch 2/10: - Training Accuracy: 67.76% - Training Loss: 0.6045 - Time Taken: 3.0201 seconds
#   - Validation Accuracy: 65.81% - Validation Loss: 0.6236
# Epoch 3/10: - Training Accuracy: 78.43% - Training Loss: 0.4922 - Time Taken: 3.0360 seconds
#   - Validation Accuracy: 83.27% - Validation Loss: 0.4012
# Epoch 4/10: - Training Accuracy: 85.11% - Training Loss: 0.3743 - Time Taken: 3.0611 seconds
#   - Validation Accuracy: 86.38% - Validation Loss: 0.3499
# Epoch 5/10: - Training Accuracy: 90.21% - Training Loss: 0.2625 - Time Taken: 3.0999 seconds
#   - Validation Accuracy: 88.92% - Validation Loss: 0.2878
# Epoch 6/10: - Training Accuracy: 93.07% - Training Loss: 0.1950 - Time Taken: 3.0242 seconds
#   - Validation Accuracy: 88.64% - Validation Loss: 0.2946
# Epoch 7/10: - Training Accuracy: 94.82% - Training Loss: 0.1540 - Time Taken: 3.0362 seconds
#   - Validation Accuracy: 89.44% - Validation Loss: 0.3111
# Epoch 8/10: - Training Accuracy: 96.11% - Training Loss: 0.1185 - Time Taken: 3.1128 seconds
#   - Validation Accuracy: 89.24% - Validation Loss: 0.2966
# Epoch 9/10: - Training Accuracy: 96.97% - Training Loss: 0.0967 - Time Taken: 3.0441 seconds
#   - Validation Accuracy: 89.34% - Validation Loss: 0.3360
# Epoch 10/10: - Training Accuracy: 97.67% - Training Loss: 0.0805 - Time Taken: 3.0332 seconds
#   - Validation Accuracy: 88.60% - Validation Loss: 0.3747
# Average Validation Accuracy: 82.17875874125875
# Training with LR=0.001, WD=1e-06, Dropout=0.3
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 55.13% - Training Loss: 0.6741 - Time Taken: 3.0217 seconds
#   - Validation Accuracy: 58.45% - Validation Loss: 0.6544
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 57.73% - Training Loss: 0.6597 - Time Taken: 3.1392 seconds
#   - Validation Accuracy: 74.14% - Validation Loss: 0.5342
# Epoch 2/10: - Training Accuracy: 73.96% - Training Loss: 0.5277 - Time Taken: 3.0234 seconds
#   - Validation Accuracy: 77.08% - Validation Loss: 0.4727
# Epoch 3/10: - Training Accuracy: 83.50% - Training Loss: 0.3823 - Time Taken: 3.0260 seconds
#   - Validation Accuracy: 86.98% - Validation Loss: 0.3231
# Epoch 4/10: - Training Accuracy: 89.88% - Training Loss: 0.2653 - Time Taken: 3.0331 seconds
#   - Validation Accuracy: 85.18% - Validation Loss: 0.3681
# Epoch 5/10: - Training Accuracy: 91.47% - Training Loss: 0.2265 - Time Taken: 3.1307 seconds
#   - Validation Accuracy: 89.18% - Validation Loss: 0.2827
# Epoch 6/10: - Training Accuracy: 93.30% - Training Loss: 0.1827 - Time Taken: 3.0249 seconds
#   - Validation Accuracy: 89.56% - Validation Loss: 0.2844
# Epoch 7/10: - Training Accuracy: 95.52% - Training Loss: 0.1345 - Time Taken: 3.0350 seconds
#   - Validation Accuracy: 89.56% - Validation Loss: 0.2987
# Epoch 8/10: - Training Accuracy: 96.77% - Training Loss: 0.1030 - Time Taken: 3.1120 seconds
#   - Validation Accuracy: 88.98% - Validation Loss: 0.3337
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 55.41% - Training Loss: 0.6727 - Time Taken: 3.0774 seconds
#   - Validation Accuracy: 59.74% - Validation Loss: 0.6624
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 84.52667124542124
# Training with LR=0.001, WD=1e-06, Dropout=0.5
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 54.62% - Training Loss: 0.6771 - Time Taken: 3.0220 seconds
#   - Validation Accuracy: 54.37% - Validation Loss: 0.6714
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 55.16% - Training Loss: 0.6712 - Time Taken: 3.0233 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6810
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 58.04% - Training Loss: 0.6628 - Time Taken: 3.1120 seconds
#   - Validation Accuracy: 56.99% - Validation Loss: 0.6741
# Epoch 2/10: - Training Accuracy: 70.42% - Training Loss: 0.5619 - Time Taken: 3.0368 seconds
#   - Validation Accuracy: 81.47% - Validation Loss: 0.4572
# Epoch 3/10: - Training Accuracy: 83.92% - Training Loss: 0.3819 - Time Taken: 3.0414 seconds
#   - Validation Accuracy: 81.23% - Validation Loss: 0.4310
# Epoch 4/10: - Training Accuracy: 88.33% - Training Loss: 0.2908 - Time Taken: 3.0382 seconds
#   - Validation Accuracy: 85.52% - Validation Loss: 0.3242
# Epoch 5/10: - Training Accuracy: 90.65% - Training Loss: 0.2393 - Time Taken: 3.1639 seconds
#   - Validation Accuracy: 88.14% - Validation Loss: 0.2938
# Epoch 6/10: - Training Accuracy: 93.05% - Training Loss: 0.1880 - Time Taken: 3.0579 seconds
#   - Validation Accuracy: 88.92% - Validation Loss: 0.2818
# Epoch 7/10: - Training Accuracy: 94.45% - Training Loss: 0.1542 - Time Taken: 3.0355 seconds
#   - Validation Accuracy: 89.14% - Validation Loss: 0.2881
# Epoch 8/10: - Training Accuracy: 95.44% - Training Loss: 0.1308 - Time Taken: 3.0617 seconds
#   - Validation Accuracy: 88.64% - Validation Loss: 0.2889
# Epoch 9/10: - Training Accuracy: 96.29% - Training Loss: 0.1085 - Time Taken: 3.1240 seconds
#   - Validation Accuracy: 89.30% - Validation Loss: 0.3230
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 82.50701121794873
# Training with LR=0.001, WD=1e-06, Dropout=0.7
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 54.62% - Training Loss: 0.6785 - Time Taken: 3.0325 seconds
#   - Validation Accuracy: 57.11% - Validation Loss: 0.6769
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 55.57% - Training Loss: 0.6712 - Time Taken: 3.0095 seconds
#   - Validation Accuracy: 72.52% - Validation Loss: 0.5711
# Epoch 2/10: - Training Accuracy: 69.58% - Training Loss: 0.5901 - Time Taken: 3.1155 seconds
#   - Validation Accuracy: 78.91% - Validation Loss: 0.4681
# Epoch 3/10: - Training Accuracy: 81.70% - Training Loss: 0.4310 - Time Taken: 3.0693 seconds
#   - Validation Accuracy: 78.17% - Validation Loss: 0.5039
# Epoch 4/10: - Training Accuracy: 87.19% - Training Loss: 0.3223 - Time Taken: 3.0466 seconds
#   - Validation Accuracy: 87.88% - Validation Loss: 0.3135
# Epoch 5/10: - Training Accuracy: 91.13% - Training Loss: 0.2333 - Time Taken: 3.0460 seconds
#   - Validation Accuracy: 89.36% - Validation Loss: 0.2821
# Epoch 6/10: - Training Accuracy: 93.67% - Training Loss: 0.1813 - Time Taken: 3.1666 seconds
#   - Validation Accuracy: 89.78% - Validation Loss: 0.2607
# Epoch 7/10: - Training Accuracy: 94.89% - Training Loss: 0.1516 - Time Taken: 3.0331 seconds
#   - Validation Accuracy: 89.50% - Validation Loss: 0.2867
# Epoch 8/10: - Training Accuracy: 96.42% - Training Loss: 0.1121 - Time Taken: 3.0374 seconds
#   - Validation Accuracy: 89.50% - Validation Loss: 0.3025
# Epoch 9/10: - Training Accuracy: 97.36% - Training Loss: 0.0863 - Time Taken: 3.0415 seconds
#   - Validation Accuracy: 89.00% - Validation Loss: 0.3765
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 55.43% - Training Loss: 0.6737 - Time Taken: 3.1528 seconds
#   - Validation Accuracy: 54.91% - Validation Loss: 0.6779
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 84.45262419871796
# Training with LR=0.0001, WD=0.0001, Dropout=0.3
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.03% - Training Loss: 0.6837 - Time Taken: 3.0217 seconds
#   - Validation Accuracy: 54.41% - Validation Loss: 0.6746
# Epoch 2/10: - Training Accuracy: 54.83% - Training Loss: 0.6725 - Time Taken: 3.0250 seconds
#   - Validation Accuracy: 54.51% - Validation Loss: 0.6841
# Epoch 3/10: - Training Accuracy: 55.32% - Training Loss: 0.6761 - Time Taken: 3.0640 seconds
#   - Validation Accuracy: 54.39% - Validation Loss: 0.6816
# Epoch 4/10: - Training Accuracy: 54.78% - Training Loss: 0.6737 - Time Taken: 3.1183 seconds
#   - Validation Accuracy: 55.17% - Validation Loss: 0.6601
# Epoch 5/10: - Training Accuracy: 55.76% - Training Loss: 0.6573 - Time Taken: 3.0193 seconds
#   - Validation Accuracy: 54.57% - Validation Loss: 0.6327
# Epoch 6/10: - Training Accuracy: 58.16% - Training Loss: 0.6724 - Time Taken: 3.0195 seconds
#   - Validation Accuracy: 58.81% - Validation Loss: 0.6687
# Epoch 7/10: - Training Accuracy: 58.57% - Training Loss: 0.6593 - Time Taken: 3.1521 seconds
#   - Validation Accuracy: 65.65% - Validation Loss: 0.6348
# Epoch 8/10: - Training Accuracy: 60.79% - Training Loss: 0.6568 - Time Taken: 3.0851 seconds
#   - Validation Accuracy: 51.54% - Validation Loss: 0.6955
# Epoch 9/10: - Training Accuracy: 53.06% - Training Loss: 0.6889 - Time Taken: 3.0139 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6860
# Epoch 10/10: - Training Accuracy: 54.17% - Training Loss: 0.6840 - Time Taken: 3.0214 seconds
#   - Validation Accuracy: 54.91% - Validation Loss: 0.6803
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 54.00% - Training Loss: 0.6841 - Time Taken: 3.1417 seconds
#   - Validation Accuracy: 54.27% - Validation Loss: 0.6762
# Epoch 2/10: - Training Accuracy: 54.74% - Training Loss: 0.6744 - Time Taken: 3.0475 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6702
# Epoch 3/10: - Training Accuracy: 55.58% - Training Loss: 0.6781 - Time Taken: 3.1052 seconds
#   - Validation Accuracy: 54.81% - Validation Loss: 0.6832
# Epoch 4/10: - Training Accuracy: 54.35% - Training Loss: 0.6803 - Time Taken: 3.0614 seconds
#   - Validation Accuracy: 54.95% - Validation Loss: 0.6731
# Epoch 5/10: - Training Accuracy: 56.70% - Training Loss: 0.6657 - Time Taken: 3.1704 seconds
#   - Validation Accuracy: 54.29% - Validation Loss: 0.6844
# Epoch 6/10: - Training Accuracy: 54.57% - Training Loss: 0.6804 - Time Taken: 3.0468 seconds
#   - Validation Accuracy: 54.59% - Validation Loss: 0.6771
# Epoch 7/10: - Training Accuracy: 54.32% - Training Loss: 0.6759 - Time Taken: 3.0340 seconds
#   - Validation Accuracy: 54.63% - Validation Loss: 0.6710
# Epoch 8/10: - Training Accuracy: 54.94% - Training Loss: 0.6696 - Time Taken: 3.0669 seconds
#   - Validation Accuracy: 55.03% - Validation Loss: 0.6632
# Epoch 9/10: - Training Accuracy: 54.76% - Training Loss: 0.6662 - Time Taken: 3.0875 seconds
#   - Validation Accuracy: 54.59% - Validation Loss: 0.6652
# Epoch 10/10: - Training Accuracy: 55.11% - Training Loss: 0.6654 - Time Taken: 3.0357 seconds
#   - Validation Accuracy: 55.17% - Validation Loss: 0.6603
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 53.25% - Training Loss: 0.6842 - Time Taken: 3.0240 seconds
#   - Validation Accuracy: 54.57% - Validation Loss: 0.6763
# Epoch 2/10: - Training Accuracy: 54.21% - Training Loss: 0.6792 - Time Taken: 3.1675 seconds
#   - Validation Accuracy: 54.45% - Validation Loss: 0.6789
# Epoch 3/10: - Training Accuracy: 55.29% - Training Loss: 0.6691 - Time Taken: 3.0573 seconds
#   - Validation Accuracy: 54.35% - Validation Loss: 0.6325
# Epoch 4/10: - Training Accuracy: 56.50% - Training Loss: 0.6830 - Time Taken: 3.0393 seconds
#   - Validation Accuracy: 57.41% - Validation Loss: 0.6688
# Epoch 5/10: - Training Accuracy: 56.21% - Training Loss: 0.6657 - Time Taken: 3.0330 seconds
#   - Validation Accuracy: 55.19% - Validation Loss: 0.6563
# Epoch 6/10: - Training Accuracy: 56.82% - Training Loss: 0.6514 - Time Taken: 3.1962 seconds
#   - Validation Accuracy: 64.94% - Validation Loss: 0.6232
# Epoch 7/10: - Training Accuracy: 67.53% - Training Loss: 0.6087 - Time Taken: 3.0688 seconds
#   - Validation Accuracy: 68.89% - Validation Loss: 0.6160
# Epoch 8/10: - Training Accuracy: 67.50% - Training Loss: 0.6231 - Time Taken: 3.0732 seconds
#   - Validation Accuracy: 65.69% - Validation Loss: 0.6334
# Epoch 9/10: - Training Accuracy: 65.26% - Training Loss: 0.6344 - Time Taken: 3.0663 seconds
#   - Validation Accuracy: 69.81% - Validation Loss: 0.6025
# Epoch 10/10: - Training Accuracy: 66.17% - Training Loss: 0.6217 - Time Taken: 3.1667 seconds
#   - Validation Accuracy: 70.97% - Validation Loss: 0.5940
# Average Validation Accuracy: 57.35777243589744
# Training with LR=0.0001, WD=0.0001, Dropout=0.5
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.36% - Training Loss: 0.6837 - Time Taken: 3.0304 seconds
#   - Validation Accuracy: 54.35% - Validation Loss: 0.6760
# Epoch 2/10: - Training Accuracy: 54.33% - Training Loss: 0.6756 - Time Taken: 3.0351 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6794
# Epoch 3/10: - Training Accuracy: 54.75% - Training Loss: 0.6657 - Time Taken: 3.0953 seconds
#   - Validation Accuracy: 54.15% - Validation Loss: 0.6564
# Epoch 4/10: - Training Accuracy: 56.53% - Training Loss: 0.6702 - Time Taken: 3.1442 seconds
#   - Validation Accuracy: 56.95% - Validation Loss: 0.6723
# Epoch 5/10: - Training Accuracy: 56.82% - Training Loss: 0.6635 - Time Taken: 3.0689 seconds
#   - Validation Accuracy: 65.83% - Validation Loss: 0.6364
# Epoch 6/10: - Training Accuracy: 67.46% - Training Loss: 0.6078 - Time Taken: 3.0496 seconds
#   - Validation Accuracy: 72.90% - Validation Loss: 0.5696
# Epoch 7/10: - Training Accuracy: 72.51% - Training Loss: 0.5604 - Time Taken: 3.2127 seconds
#   - Validation Accuracy: 75.12% - Validation Loss: 0.5292
# Epoch 8/10: - Training Accuracy: 60.77% - Training Loss: 0.6343 - Time Taken: 3.0706 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6815
# Epoch 9/10: - Training Accuracy: 53.97% - Training Loss: 0.6802 - Time Taken: 3.0631 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6767
# Epoch 10/10: - Training Accuracy: 54.25% - Training Loss: 0.6760 - Time Taken: 3.0591 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6738
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 53.14% - Training Loss: 0.6837 - Time Taken: 3.2360 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6756
# Epoch 2/10: - Training Accuracy: 54.18% - Training Loss: 0.6716 - Time Taken: 3.0334 seconds
#   - Validation Accuracy: 54.23% - Validation Loss: 0.6430
# Epoch 3/10: - Training Accuracy: 55.54% - Training Loss: 0.6659 - Time Taken: 3.0574 seconds
#   - Validation Accuracy: 55.87% - Validation Loss: 0.6594
# Epoch 4/10: - Training Accuracy: 54.50% - Training Loss: 0.6733 - Time Taken: 3.0624 seconds
#   - Validation Accuracy: 53.17% - Validation Loss: 0.6888
# Epoch 5/10: - Training Accuracy: 54.03% - Training Loss: 0.6857 - Time Taken: 3.1441 seconds
#   - Validation Accuracy: 54.07% - Validation Loss: 0.6815
# Epoch 6/10: - Training Accuracy: 55.33% - Training Loss: 0.6909 - Time Taken: 3.0503 seconds
#   - Validation Accuracy: 54.67% - Validation Loss: 0.6659
# Epoch 7/10: - Training Accuracy: 60.58% - Training Loss: 0.6515 - Time Taken: 3.0677 seconds
#   - Validation Accuracy: 64.16% - Validation Loss: 0.6431
# Epoch 8/10: - Training Accuracy: 69.04% - Training Loss: 0.6036 - Time Taken: 3.1585 seconds
#   - Validation Accuracy: 69.83% - Validation Loss: 0.5932
# Epoch 9/10: - Training Accuracy: 68.81% - Training Loss: 0.6034 - Time Taken: 3.0986 seconds
#   - Validation Accuracy: 67.01% - Validation Loss: 0.6229
# Epoch 10/10: - Training Accuracy: 70.38% - Training Loss: 0.5928 - Time Taken: 3.0905 seconds
#   - Validation Accuracy: 68.69% - Validation Loss: 0.5986
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 53.16% - Training Loss: 0.6844 - Time Taken: 3.0487 seconds
#   - Validation Accuracy: 55.01% - Validation Loss: 0.6756
# Epoch 2/10: - Training Accuracy: 54.48% - Training Loss: 0.6729 - Time Taken: 3.1927 seconds
#   - Validation Accuracy: 55.45% - Validation Loss: 0.6581
# Epoch 3/10: - Training Accuracy: 56.69% - Training Loss: 0.6708 - Time Taken: 3.0605 seconds
#   - Validation Accuracy: 56.73% - Validation Loss: 0.6589
# Epoch 4/10: - Training Accuracy: 56.81% - Training Loss: 0.6713 - Time Taken: 3.0558 seconds
#   - Validation Accuracy: 55.09% - Validation Loss: 0.6685
# Epoch 5/10: - Training Accuracy: 55.71% - Training Loss: 0.6634 - Time Taken: 3.0406 seconds
#   - Validation Accuracy: 56.09% - Validation Loss: 0.6575
# Epoch 6/10: - Training Accuracy: 60.53% - Training Loss: 0.6533 - Time Taken: 3.2205 seconds
#   - Validation Accuracy: 65.48% - Validation Loss: 0.6223
# Epoch 7/10: - Training Accuracy: 67.18% - Training Loss: 0.6202 - Time Taken: 3.0713 seconds
#   - Validation Accuracy: 71.33% - Validation Loss: 0.5946
# Epoch 8/10: - Training Accuracy: 67.51% - Training Loss: 0.6148 - Time Taken: 3.1041 seconds
#   - Validation Accuracy: 67.67% - Validation Loss: 0.6095
# Epoch 9/10: - Training Accuracy: 69.46% - Training Loss: 0.6039 - Time Taken: 3.0825 seconds
#   - Validation Accuracy: 72.10% - Validation Loss: 0.5853
# Epoch 10/10: - Training Accuracy: 57.34% - Training Loss: 0.6704 - Time Taken: 3.1300 seconds
#   - Validation Accuracy: 68.83% - Validation Loss: 0.6748
# Average Validation Accuracy: 60.50948183760684
# Training with LR=0.0001, WD=0.0001, Dropout=0.7
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.83% - Training Loss: 0.6835 - Time Taken: 3.0409 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6764
# Epoch 2/10: - Training Accuracy: 54.35% - Training Loss: 0.6774 - Time Taken: 3.0155 seconds
#   - Validation Accuracy: 56.31% - Validation Loss: 0.7043
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 53.82% - Training Loss: 0.6841 - Time Taken: 3.1781 seconds
#   - Validation Accuracy: 54.17% - Validation Loss: 0.6772
# Epoch 2/10: - Training Accuracy: 55.62% - Training Loss: 0.6757 - Time Taken: 3.1029 seconds
#   - Validation Accuracy: 56.23% - Validation Loss: 0.7565
# Epoch 3/10: - Training Accuracy: 54.49% - Training Loss: 0.6764 - Time Taken: 3.0658 seconds
#   - Validation Accuracy: 55.65% - Validation Loss: 0.6702
# Epoch 4/10: - Training Accuracy: 54.82% - Training Loss: 0.6665 - Time Taken: 3.0515 seconds
#   - Validation Accuracy: 56.31% - Validation Loss: 0.6523
# Epoch 5/10: - Training Accuracy: 60.21% - Training Loss: 0.6491 - Time Taken: 3.2009 seconds
#   - Validation Accuracy: 72.06% - Validation Loss: 0.5994
# Epoch 6/10: - Training Accuracy: 61.07% - Training Loss: 0.6441 - Time Taken: 3.0424 seconds
#   - Validation Accuracy: 56.83% - Validation Loss: 0.6558
# Epoch 7/10: - Training Accuracy: 63.36% - Training Loss: 0.6288 - Time Taken: 3.0696 seconds
#   - Validation Accuracy: 72.52% - Validation Loss: 0.5822
# Epoch 8/10: - Training Accuracy: 69.33% - Training Loss: 0.5957 - Time Taken: 3.1360 seconds
#   - Validation Accuracy: 67.09% - Validation Loss: 0.6472
# Epoch 9/10: - Training Accuracy: 53.70% - Training Loss: 0.6889 - Time Taken: 3.2244 seconds
#   - Validation Accuracy: 54.29% - Validation Loss: 0.6816
# Epoch 10/10: - Training Accuracy: 58.79% - Training Loss: 0.6725 - Time Taken: 3.0519 seconds
#   - Validation Accuracy: 61.06% - Validation Loss: 0.6719
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 54.55% - Training Loss: 0.6838 - Time Taken: 3.0405 seconds
#   - Validation Accuracy: 54.33% - Validation Loss: 0.6768
# Epoch 2/10: - Training Accuracy: 54.31% - Training Loss: 0.6754 - Time Taken: 3.0851 seconds
#   - Validation Accuracy: 56.83% - Validation Loss: 0.6595
# Epoch 3/10: - Training Accuracy: 55.27% - Training Loss: 0.6712 - Time Taken: 3.1036 seconds
#   - Validation Accuracy: 54.41% - Validation Loss: 0.6826
# Epoch 4/10: - Training Accuracy: 54.89% - Training Loss: 0.6772 - Time Taken: 3.0232 seconds
#   - Validation Accuracy: 54.03% - Validation Loss: 0.6806
# Epoch 5/10: - Training Accuracy: 54.64% - Training Loss: 0.6771 - Time Taken: 3.0647 seconds
#   - Validation Accuracy: 54.67% - Validation Loss: 0.6728
# Epoch 6/10: - Training Accuracy: 54.76% - Training Loss: 0.6710 - Time Taken: 3.2087 seconds
#   - Validation Accuracy: 54.75% - Validation Loss: 0.6656
# Epoch 7/10: - Training Accuracy: 55.02% - Training Loss: 0.6663 - Time Taken: 3.0206 seconds
#   - Validation Accuracy: 55.03% - Validation Loss: 0.6616
# Epoch 8/10: - Training Accuracy: 54.58% - Training Loss: 0.6632 - Time Taken: 3.0209 seconds
#   - Validation Accuracy: 56.05% - Validation Loss: 0.6543
# Epoch 9/10: - Training Accuracy: 56.54% - Training Loss: 0.6693 - Time Taken: 3.0316 seconds
#   - Validation Accuracy: 54.63% - Validation Loss: 0.6789
# Epoch 10/10: - Training Accuracy: 54.51% - Training Loss: 0.6769 - Time Taken: 3.2217 seconds
#   - Validation Accuracy: 54.71% - Validation Loss: 0.6716
# Average Validation Accuracy: 57.60550213675213
# Training with LR=0.0001, WD=1e-05, Dropout=0.3
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.66% - Training Loss: 0.6827 - Time Taken: 3.0441 seconds
#   - Validation Accuracy: 54.29% - Validation Loss: 0.6749
# Epoch 2/10: - Training Accuracy: 54.51% - Training Loss: 0.6715 - Time Taken: 3.0254 seconds
#   - Validation Accuracy: 57.23% - Validation Loss: 0.6531
# Epoch 3/10: - Training Accuracy: 55.68% - Training Loss: 0.6654 - Time Taken: 3.0449 seconds
#   - Validation Accuracy: 55.67% - Validation Loss: 0.6576
# Epoch 4/10: - Training Accuracy: 55.85% - Training Loss: 0.6616 - Time Taken: 3.1269 seconds
#   - Validation Accuracy: 55.81% - Validation Loss: 0.6597
# Epoch 5/10: - Training Accuracy: 64.88% - Training Loss: 0.6236 - Time Taken: 3.0342 seconds
#   - Validation Accuracy: 68.53% - Validation Loss: 0.6321
# Epoch 6/10: - Training Accuracy: 63.29% - Training Loss: 0.6276 - Time Taken: 3.0499 seconds
#   - Validation Accuracy: 71.71% - Validation Loss: 0.5858
# Epoch 7/10: - Training Accuracy: 71.29% - Training Loss: 0.5864 - Time Taken: 3.1180 seconds
#   - Validation Accuracy: 72.02% - Validation Loss: 0.5774
# Epoch 8/10: - Training Accuracy: 70.62% - Training Loss: 0.5888 - Time Taken: 3.0747 seconds
#   - Validation Accuracy: 69.31% - Validation Loss: 0.5989
# Epoch 9/10: - Training Accuracy: 71.21% - Training Loss: 0.5806 - Time Taken: 3.0331 seconds
#   - Validation Accuracy: 72.88% - Validation Loss: 0.5675
# Epoch 10/10: - Training Accuracy: 69.61% - Training Loss: 0.5862 - Time Taken: 3.0487 seconds
#   - Validation Accuracy: 62.68% - Validation Loss: 0.6238
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 54.18% - Training Loss: 0.6817 - Time Taken: 3.2074 seconds
#   - Validation Accuracy: 55.23% - Validation Loss: 0.6750
# Epoch 2/10: - Training Accuracy: 54.83% - Training Loss: 0.6717 - Time Taken: 3.0295 seconds
#   - Validation Accuracy: 54.83% - Validation Loss: 0.6626
# Epoch 3/10: - Training Accuracy: 54.48% - Training Loss: 0.6719 - Time Taken: 3.0187 seconds
#   - Validation Accuracy: 54.79% - Validation Loss: 0.6696
# Epoch 4/10: - Training Accuracy: 58.08% - Training Loss: 0.6525 - Time Taken: 3.0177 seconds
#   - Validation Accuracy: 57.83% - Validation Loss: 0.6523
# Epoch 5/10: - Training Accuracy: 60.29% - Training Loss: 0.6536 - Time Taken: 3.2350 seconds
#   - Validation Accuracy: 54.05% - Validation Loss: 0.6839
# Epoch 6/10: - Training Accuracy: 54.48% - Training Loss: 0.6796 - Time Taken: 3.0191 seconds
#   - Validation Accuracy: 54.17% - Validation Loss: 0.6754
# Epoch 7/10: - Training Accuracy: 54.74% - Training Loss: 0.6663 - Time Taken: 3.0143 seconds
#   - Validation Accuracy: 57.11% - Validation Loss: 0.6452
# Epoch 8/10: - Training Accuracy: 62.99% - Training Loss: 0.6474 - Time Taken: 3.0437 seconds
#   - Validation Accuracy: 62.76% - Validation Loss: 0.6398
# Epoch 9/10: - Training Accuracy: 62.71% - Training Loss: 0.6280 - Time Taken: 3.1223 seconds
#   - Validation Accuracy: 69.73% - Validation Loss: 0.5928
# Epoch 10/10: - Training Accuracy: 62.81% - Training Loss: 0.6333 - Time Taken: 3.0459 seconds
#   - Validation Accuracy: 62.24% - Validation Loss: 0.6460
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 52.81% - Training Loss: 0.6840 - Time Taken: 3.0619 seconds
#   - Validation Accuracy: 54.59% - Validation Loss: 0.6757
# Epoch 2/10: - Training Accuracy: 54.43% - Training Loss: 0.6758 - Time Taken: 3.1409 seconds
#   - Validation Accuracy: 59.35% - Validation Loss: 0.6518
# Epoch 3/10: - Training Accuracy: 56.18% - Training Loss: 0.6648 - Time Taken: 3.0791 seconds
#   - Validation Accuracy: 55.73% - Validation Loss: 0.6690
# Epoch 4/10: - Training Accuracy: 55.63% - Training Loss: 0.6759 - Time Taken: 3.0261 seconds
#   - Validation Accuracy: 54.15% - Validation Loss: 0.6862
# Epoch 5/10: - Training Accuracy: 54.61% - Training Loss: 0.6811 - Time Taken: 3.0369 seconds
#   - Validation Accuracy: 54.69% - Validation Loss: 0.6751
# Epoch 6/10: - Training Accuracy: 56.08% - Training Loss: 0.6923 - Time Taken: 3.1607 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.9289
# Epoch 7/10: - Training Accuracy: 56.23% - Training Loss: 0.6890 - Time Taken: 3.0431 seconds
#   - Validation Accuracy: 58.01% - Validation Loss: 0.6722
# Epoch 8/10: - Training Accuracy: 57.57% - Training Loss: 0.6701 - Time Taken: 3.0314 seconds
#   - Validation Accuracy: 58.05% - Validation Loss: 0.6662
# Epoch 9/10: - Training Accuracy: 57.83% - Training Loss: 0.6635 - Time Taken: 3.0346 seconds
#   - Validation Accuracy: 58.11% - Validation Loss: 0.6595
# Epoch 10/10: - Training Accuracy: 58.03% - Training Loss: 0.6523 - Time Taken: 3.1697 seconds
#   - Validation Accuracy: 58.37% - Validation Loss: 0.6458
# Average Validation Accuracy: 59.60069444444444
# Training with LR=0.0001, WD=1e-05, Dropout=0.5
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.32% - Training Loss: 0.6832 - Time Taken: 3.0324 seconds
#   - Validation Accuracy: 54.61% - Validation Loss: 0.6743
# Epoch 2/10: - Training Accuracy: 54.71% - Training Loss: 0.6729 - Time Taken: 3.0388 seconds
#   - Validation Accuracy: 54.61% - Validation Loss: 0.6657
# Epoch 3/10: - Training Accuracy: 58.31% - Training Loss: 0.6631 - Time Taken: 3.0654 seconds
#   - Validation Accuracy: 54.17% - Validation Loss: 0.6766
# Epoch 4/10: - Training Accuracy: 55.54% - Training Loss: 0.6712 - Time Taken: 3.1333 seconds
#   - Validation Accuracy: 57.23% - Validation Loss: 0.6643
# Epoch 5/10: - Training Accuracy: 58.17% - Training Loss: 0.6658 - Time Taken: 3.0562 seconds
#   - Validation Accuracy: 54.57% - Validation Loss: 0.6745
# Epoch 6/10: - Training Accuracy: 54.72% - Training Loss: 0.6729 - Time Taken: 3.0399 seconds
#   - Validation Accuracy: 56.57% - Validation Loss: 0.6666
# Epoch 7/10: - Training Accuracy: 59.90% - Training Loss: 0.6566 - Time Taken: 3.1709 seconds
#   - Validation Accuracy: 56.03% - Validation Loss: 0.6743
# Epoch 8/10: - Training Accuracy: 63.12% - Training Loss: 0.6476 - Time Taken: 3.0924 seconds
#   - Validation Accuracy: 65.91% - Validation Loss: 0.6345
# Epoch 9/10: - Training Accuracy: 69.73% - Training Loss: 0.6152 - Time Taken: 3.0378 seconds
#   - Validation Accuracy: 71.59% - Validation Loss: 0.5931
# Epoch 10/10: - Training Accuracy: 72.79% - Training Loss: 0.5647 - Time Taken: 3.0385 seconds
#   - Validation Accuracy: 75.52% - Validation Loss: 0.5231
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 54.08% - Training Loss: 0.6836 - Time Taken: 3.1891 seconds
#   - Validation Accuracy: 54.89% - Validation Loss: 0.6750
# Epoch 2/10: - Training Accuracy: 54.79% - Training Loss: 0.6737 - Time Taken: 3.0480 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6578
# Epoch 3/10: - Training Accuracy: 60.66% - Training Loss: 0.6667 - Time Taken: 3.0781 seconds
#   - Validation Accuracy: 69.69% - Validation Loss: 0.6006
# Epoch 4/10: - Training Accuracy: 66.99% - Training Loss: 0.6215 - Time Taken: 3.0656 seconds
#   - Validation Accuracy: 70.51% - Validation Loss: 0.6072
# Epoch 5/10: - Training Accuracy: 66.45% - Training Loss: 0.6250 - Time Taken: 3.1806 seconds
#   - Validation Accuracy: 70.75% - Validation Loss: 0.5945
# Epoch 6/10: - Training Accuracy: 63.99% - Training Loss: 0.6418 - Time Taken: 3.0701 seconds
#   - Validation Accuracy: 57.87% - Validation Loss: 0.6702
# Epoch 7/10: - Training Accuracy: 55.99% - Training Loss: 0.6614 - Time Taken: 3.0720 seconds
#   - Validation Accuracy: 57.97% - Validation Loss: 0.6517
# Epoch 8/10: - Training Accuracy: 62.58% - Training Loss: 0.6372 - Time Taken: 3.1226 seconds
#   - Validation Accuracy: 70.33% - Validation Loss: 0.6072
# Epoch 9/10: - Training Accuracy: 70.00% - Training Loss: 0.5936 - Time Taken: 3.1136 seconds
#   - Validation Accuracy: 72.30% - Validation Loss: 0.5598
# Epoch 10/10: - Training Accuracy: 72.30% - Training Loss: 0.5674 - Time Taken: 3.0424 seconds
#   - Validation Accuracy: 73.72% - Validation Loss: 0.5491
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 52.48% - Training Loss: 0.6845 - Time Taken: 3.0247 seconds
#   - Validation Accuracy: 54.09% - Validation Loss: 0.6756
# Epoch 2/10: - Training Accuracy: 55.07% - Training Loss: 0.6687 - Time Taken: 3.1288 seconds
#   - Validation Accuracy: 56.91% - Validation Loss: 0.6498
# Epoch 3/10: - Training Accuracy: 55.39% - Training Loss: 0.6792 - Time Taken: 3.0339 seconds
#   - Validation Accuracy: 54.65% - Validation Loss: 0.6693
# Epoch 4/10: - Training Accuracy: 57.36% - Training Loss: 0.6574 - Time Taken: 3.0250 seconds
#   - Validation Accuracy: 63.78% - Validation Loss: 0.6324
# Epoch 5/10: - Training Accuracy: 59.66% - Training Loss: 0.6497 - Time Taken: 3.0202 seconds
#   - Validation Accuracy: 57.35% - Validation Loss: 0.6562
# Epoch 6/10: - Training Accuracy: 60.49% - Training Loss: 0.6600 - Time Taken: 3.1563 seconds
#   - Validation Accuracy: 70.13% - Validation Loss: 0.6183
# Epoch 7/10: - Training Accuracy: 60.31% - Training Loss: 0.6607 - Time Taken: 3.0247 seconds
#   - Validation Accuracy: 58.55% - Validation Loss: 0.6737
# Epoch 8/10: - Training Accuracy: 56.65% - Training Loss: 0.6735 - Time Taken: 3.0211 seconds
#   - Validation Accuracy: 54.15% - Validation Loss: 0.6800
# Epoch 9/10: - Training Accuracy: 57.71% - Training Loss: 0.6703 - Time Taken: 3.0448 seconds
#   - Validation Accuracy: 59.25% - Validation Loss: 0.6580
# Epoch 10/10: - Training Accuracy: 61.39% - Training Loss: 0.6524 - Time Taken: 3.1261 seconds
#   - Validation Accuracy: 67.01% - Validation Loss: 0.6255
# Average Validation Accuracy: 61.62727029914528
# Training with LR=0.0001, WD=1e-05, Dropout=0.7
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.25% - Training Loss: 0.6843 - Time Taken: 3.0042 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6749
# Epoch 2/10: - Training Accuracy: 56.34% - Training Loss: 0.6698 - Time Taken: 3.0159 seconds
#   - Validation Accuracy: 61.54% - Validation Loss: 0.6452
# Epoch 3/10: - Training Accuracy: 66.07% - Training Loss: 0.6298 - Time Taken: 3.0955 seconds
#   - Validation Accuracy: 55.03% - Validation Loss: 0.6672
# Epoch 4/10: - Training Accuracy: 55.31% - Training Loss: 0.6670 - Time Taken: 3.0830 seconds
#   - Validation Accuracy: 56.77% - Validation Loss: 0.6620
# Epoch 5/10: - Training Accuracy: 55.32% - Training Loss: 0.6592 - Time Taken: 3.0384 seconds
#   - Validation Accuracy: 56.77% - Validation Loss: 0.6509
# Epoch 6/10: - Training Accuracy: 63.32% - Training Loss: 0.6356 - Time Taken: 3.0434 seconds
#   - Validation Accuracy: 60.64% - Validation Loss: 0.6362
# Epoch 7/10: - Training Accuracy: 66.65% - Training Loss: 0.6105 - Time Taken: 3.1575 seconds
#   - Validation Accuracy: 64.40% - Validation Loss: 0.6055
# Epoch 8/10: - Training Accuracy: 63.79% - Training Loss: 0.6197 - Time Taken: 3.0344 seconds
#   - Validation Accuracy: 57.43% - Validation Loss: 0.6514
# Epoch 9/10: - Training Accuracy: 61.29% - Training Loss: 0.6284 - Time Taken: 3.0353 seconds
#   - Validation Accuracy: 68.49% - Validation Loss: 0.6052
# Epoch 10/10: - Training Accuracy: 70.22% - Training Loss: 0.5933 - Time Taken: 3.0423 seconds
#   - Validation Accuracy: 69.87% - Validation Loss: 0.6023
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 53.27% - Training Loss: 0.6835 - Time Taken: 3.1114 seconds
#   - Validation Accuracy: 54.33% - Validation Loss: 0.6738
# Epoch 2/10: - Training Accuracy: 55.09% - Training Loss: 0.6701 - Time Taken: 3.0111 seconds
#   - Validation Accuracy: 54.31% - Validation Loss: 0.6699
# Epoch 3/10: - Training Accuracy: 55.57% - Training Loss: 0.6633 - Time Taken: 3.0133 seconds
#   - Validation Accuracy: 54.59% - Validation Loss: 0.6832
# Epoch 4/10: - Training Accuracy: 56.32% - Training Loss: 0.6695 - Time Taken: 3.0597 seconds
#   - Validation Accuracy: 56.37% - Validation Loss: 0.6586
# Epoch 5/10: - Training Accuracy: 61.59% - Training Loss: 0.6379 - Time Taken: 3.1063 seconds
#   - Validation Accuracy: 66.29% - Validation Loss: 0.6058
# Epoch 6/10: - Training Accuracy: 64.53% - Training Loss: 0.6291 - Time Taken: 3.0120 seconds
#   - Validation Accuracy: 54.83% - Validation Loss: 0.6661
# Epoch 7/10: - Training Accuracy: 56.80% - Training Loss: 0.6587 - Time Taken: 3.0041 seconds
#   - Validation Accuracy: 56.93% - Validation Loss: 0.6538
# Epoch 8/10: - Training Accuracy: 62.32% - Training Loss: 0.6363 - Time Taken: 3.1101 seconds
#   - Validation Accuracy: 70.51% - Validation Loss: 0.5950
# Epoch 9/10: - Training Accuracy: 63.65% - Training Loss: 0.6237 - Time Taken: 3.0373 seconds
#   - Validation Accuracy: 71.23% - Validation Loss: 0.5768
# Epoch 10/10: - Training Accuracy: 70.81% - Training Loss: 0.5787 - Time Taken: 3.0191 seconds
#   - Validation Accuracy: 72.58% - Validation Loss: 0.5657
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 53.11% - Training Loss: 0.6842 - Time Taken: 3.0254 seconds
#   - Validation Accuracy: 54.53% - Validation Loss: 0.6750
# Epoch 2/10: - Training Accuracy: 54.82% - Training Loss: 0.6704 - Time Taken: 3.1636 seconds
#   - Validation Accuracy: 54.27% - Validation Loss: 0.6884
# Epoch 3/10: - Training Accuracy: 54.89% - Training Loss: 0.6724 - Time Taken: 3.0258 seconds
#   - Validation Accuracy: 58.07% - Validation Loss: 0.6590
# Epoch 4/10: - Training Accuracy: 57.76% - Training Loss: 0.6776 - Time Taken: 3.0259 seconds
#   - Validation Accuracy: 56.95% - Validation Loss: 0.6692
# Epoch 5/10: - Training Accuracy: 57.10% - Training Loss: 0.6638 - Time Taken: 3.0469 seconds
#   - Validation Accuracy: 58.99% - Validation Loss: 0.6510
# Epoch 6/10: - Training Accuracy: 61.31% - Training Loss: 0.6381 - Time Taken: 3.1310 seconds
#   - Validation Accuracy: 68.69% - Validation Loss: 0.6027
# Epoch 7/10: - Training Accuracy: 68.00% - Training Loss: 0.6027 - Time Taken: 3.0395 seconds
#   - Validation Accuracy: 71.61% - Validation Loss: 0.5774
# Epoch 8/10: - Training Accuracy: 70.65% - Training Loss: 0.5772 - Time Taken: 3.0437 seconds
#   - Validation Accuracy: 71.81% - Validation Loss: 0.5638
# Epoch 9/10: - Training Accuracy: 69.52% - Training Loss: 0.5884 - Time Taken: 3.0838 seconds
#   - Validation Accuracy: 69.31% - Validation Loss: 0.5816
# Epoch 10/10: - Training Accuracy: 72.23% - Training Loss: 0.5635 - Time Taken: 3.0890 seconds
#   - Validation Accuracy: 73.36% - Validation Loss: 0.5510
# Average Validation Accuracy: 61.82024572649573
# Training with LR=0.0001, WD=1e-06, Dropout=0.3
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.93% - Training Loss: 0.6822 - Time Taken: 3.0096 seconds
#   - Validation Accuracy: 54.69% - Validation Loss: 0.6754
# Epoch 2/10: - Training Accuracy: 54.66% - Training Loss: 0.6715 - Time Taken: 3.0169 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6227
# Epoch 3/10: - Training Accuracy: 60.12% - Training Loss: 0.6414 - Time Taken: 3.1263 seconds
#   - Validation Accuracy: 70.87% - Validation Loss: 0.5785
# Epoch 4/10: - Training Accuracy: 63.61% - Training Loss: 0.6336 - Time Taken: 3.0272 seconds
#   - Validation Accuracy: 58.75% - Validation Loss: 0.6453
# Epoch 5/10: - Training Accuracy: 57.82% - Training Loss: 0.6453 - Time Taken: 3.0249 seconds
#   - Validation Accuracy: 57.13% - Validation Loss: 0.6483
# Epoch 6/10: - Training Accuracy: 65.19% - Training Loss: 0.6351 - Time Taken: 3.0208 seconds
#   - Validation Accuracy: 71.11% - Validation Loss: 0.6171
# Epoch 7/10: - Training Accuracy: 65.39% - Training Loss: 0.6319 - Time Taken: 3.1552 seconds
#   - Validation Accuracy: 54.27% - Validation Loss: 0.6739
# Epoch 8/10: - Training Accuracy: 61.84% - Training Loss: 0.6319 - Time Taken: 3.0194 seconds
#   - Validation Accuracy: 67.73% - Validation Loss: 0.6001
# Epoch 9/10: - Training Accuracy: 71.92% - Training Loss: 0.5721 - Time Taken: 3.0224 seconds
#   - Validation Accuracy: 75.00% - Validation Loss: 0.5421
# Epoch 10/10: - Training Accuracy: 73.14% - Training Loss: 0.5385 - Time Taken: 3.0447 seconds
#   - Validation Accuracy: 76.18% - Validation Loss: 0.5103
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 54.16% - Training Loss: 0.6819 - Time Taken: 3.1095 seconds
#   - Validation Accuracy: 54.69% - Validation Loss: 0.6705
# Epoch 2/10: - Training Accuracy: 56.69% - Training Loss: 0.6695 - Time Taken: 3.0072 seconds
#   - Validation Accuracy: 58.15% - Validation Loss: 0.6747
# Epoch 3/10: - Training Accuracy: 57.20% - Training Loss: 0.6638 - Time Taken: 3.0247 seconds
#   - Validation Accuracy: 62.28% - Validation Loss: 0.6397
# Epoch 4/10: - Training Accuracy: 65.37% - Training Loss: 0.6234 - Time Taken: 3.0720 seconds
#   - Validation Accuracy: 70.73% - Validation Loss: 0.5914
# Epoch 5/10: - Training Accuracy: 60.13% - Training Loss: 0.6461 - Time Taken: 3.0697 seconds
#   - Validation Accuracy: 61.56% - Validation Loss: 0.6285
# Epoch 6/10: - Training Accuracy: 65.87% - Training Loss: 0.6166 - Time Taken: 3.0280 seconds
#   - Validation Accuracy: 67.69% - Validation Loss: 0.6200
# Epoch 7/10: - Training Accuracy: 65.13% - Training Loss: 0.6310 - Time Taken: 3.0185 seconds
#   - Validation Accuracy: 62.82% - Validation Loss: 0.6422
# Epoch 8/10: - Training Accuracy: 63.37% - Training Loss: 0.6393 - Time Taken: 3.1478 seconds
#   - Validation Accuracy: 64.62% - Validation Loss: 0.6325
# Epoch 9/10: - Training Accuracy: 64.92% - Training Loss: 0.6300 - Time Taken: 3.0378 seconds
#   - Validation Accuracy: 70.19% - Validation Loss: 0.5998
# Epoch 10/10: - Training Accuracy: 63.24% - Training Loss: 0.6296 - Time Taken: 3.0374 seconds
#   - Validation Accuracy: 54.41% - Validation Loss: 0.6828
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 52.37% - Training Loss: 0.6837 - Time Taken: 3.0223 seconds
#   - Validation Accuracy: 55.53% - Validation Loss: 0.6747
# Epoch 2/10: - Training Accuracy: 56.49% - Training Loss: 0.6690 - Time Taken: 3.1675 seconds
#   - Validation Accuracy: 66.67% - Validation Loss: 0.6859
# Epoch 3/10: - Training Accuracy: 62.54% - Training Loss: 0.6500 - Time Taken: 3.0214 seconds
#   - Validation Accuracy: 68.47% - Validation Loss: 0.6336
# Epoch 4/10: - Training Accuracy: 63.92% - Training Loss: 0.6499 - Time Taken: 3.0229 seconds
#   - Validation Accuracy: 63.50% - Validation Loss: 0.6535
# Epoch 5/10: - Training Accuracy: 63.18% - Training Loss: 0.6471 - Time Taken: 3.0760 seconds
#   - Validation Accuracy: 64.06% - Validation Loss: 0.6383
# Epoch 6/10: - Training Accuracy: 64.00% - Training Loss: 0.6357 - Time Taken: 3.1232 seconds
#   - Validation Accuracy: 64.86% - Validation Loss: 0.6333
# Epoch 7/10: - Training Accuracy: 65.92% - Training Loss: 0.6244 - Time Taken: 3.0300 seconds
#   - Validation Accuracy: 66.95% - Validation Loss: 0.6242
# Epoch 8/10: - Training Accuracy: 67.34% - Training Loss: 0.6136 - Time Taken: 3.0348 seconds
#   - Validation Accuracy: 63.90% - Validation Loss: 0.6321
# Epoch 9/10: - Training Accuracy: 64.97% - Training Loss: 0.6114 - Time Taken: 3.1135 seconds
#   - Validation Accuracy: 68.69% - Validation Loss: 0.5928
# Epoch 10/10: - Training Accuracy: 68.31% - Training Loss: 0.6071 - Time Taken: 3.0404 seconds
#   - Validation Accuracy: 73.16% - Validation Loss: 0.5709
# Average Validation Accuracy: 64.09254807692308
# Training with LR=0.0001, WD=1e-06, Dropout=0.5
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 53.22% - Training Loss: 0.6837 - Time Taken: 3.0137 seconds
#   - Validation Accuracy: 54.11% - Validation Loss: 0.6758
# Epoch 2/10: - Training Accuracy: 54.07% - Training Loss: 0.6725 - Time Taken: 3.0200 seconds
#   - Validation Accuracy: 54.81% - Validation Loss: 0.6749
# Epoch 3/10: - Training Accuracy: 60.71% - Training Loss: 0.6550 - Time Taken: 3.1790 seconds
#   - Validation Accuracy: 54.95% - Validation Loss: 0.6833
# Epoch 4/10: - Training Accuracy: 64.74% - Training Loss: 0.6357 - Time Taken: 3.0379 seconds
#   - Validation Accuracy: 67.57% - Validation Loss: 0.6245
# Epoch 5/10: - Training Accuracy: 64.18% - Training Loss: 0.6437 - Time Taken: 3.0286 seconds
#   - Validation Accuracy: 60.40% - Validation Loss: 0.6585
# Epoch 6/10: - Training Accuracy: 64.56% - Training Loss: 0.6288 - Time Taken: 3.0491 seconds
#   - Validation Accuracy: 68.91% - Validation Loss: 0.6056
# Epoch 7/10: - Training Accuracy: 66.09% - Training Loss: 0.6277 - Time Taken: 3.1770 seconds
#   - Validation Accuracy: 66.57% - Validation Loss: 0.6174
# Epoch 8/10: - Training Accuracy: 67.31% - Training Loss: 0.6139 - Time Taken: 3.0341 seconds
#   - Validation Accuracy: 70.77% - Validation Loss: 0.5898
# Epoch 9/10: - Training Accuracy: 69.65% - Training Loss: 0.6040 - Time Taken: 3.0297 seconds
#   - Validation Accuracy: 71.43% - Validation Loss: 0.5895
# Epoch 10/10: - Training Accuracy: 69.62% - Training Loss: 0.6025 - Time Taken: 3.0853 seconds
#   - Validation Accuracy: 70.09% - Validation Loss: 0.5930
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 53.89% - Training Loss: 0.6831 - Time Taken: 3.0664 seconds
#   - Validation Accuracy: 54.43% - Validation Loss: 0.6752
# Epoch 2/10: - Training Accuracy: 55.08% - Training Loss: 0.6667 - Time Taken: 3.0019 seconds
#   - Validation Accuracy: 54.81% - Validation Loss: 0.6806
# Early stopping: Validation loss has not decreased for 3 epochs.
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 52.76% - Training Loss: 0.6852 - Time Taken: 3.0121 seconds
#   - Validation Accuracy: 54.15% - Validation Loss: 0.6779
# Epoch 2/10: - Training Accuracy: 55.20% - Training Loss: 0.6740 - Time Taken: 3.1309 seconds
#   - Validation Accuracy: 56.31% - Validation Loss: 0.6632
# Epoch 3/10: - Training Accuracy: 66.08% - Training Loss: 0.6343 - Time Taken: 3.0501 seconds
#   - Validation Accuracy: 70.51% - Validation Loss: 0.6028
# Epoch 4/10: - Training Accuracy: 67.90% - Training Loss: 0.6152 - Time Taken: 3.0344 seconds
#   - Validation Accuracy: 72.10% - Validation Loss: 0.6069
# Epoch 5/10: - Training Accuracy: 59.07% - Training Loss: 0.6656 - Time Taken: 3.0278 seconds
#   - Validation Accuracy: 52.58% - Validation Loss: 0.6862
# Epoch 6/10: - Training Accuracy: 58.50% - Training Loss: 0.6596 - Time Taken: 3.1309 seconds
#   - Validation Accuracy: 70.31% - Validation Loss: 0.6011
# Epoch 7/10: - Training Accuracy: 68.39% - Training Loss: 0.6062 - Time Taken: 3.0283 seconds
#   - Validation Accuracy: 71.09% - Validation Loss: 0.5873
# Epoch 8/10: - Training Accuracy: 70.44% - Training Loss: 0.5919 - Time Taken: 3.0282 seconds
#   - Validation Accuracy: 72.16% - Validation Loss: 0.5799
# Epoch 9/10: - Training Accuracy: 71.02% - Training Loss: 0.5909 - Time Taken: 3.0544 seconds
#   - Validation Accuracy: 73.42% - Validation Loss: 0.5657
# Epoch 10/10: - Training Accuracy: 69.03% - Training Loss: 0.5982 - Time Taken: 3.1373 seconds
#   - Validation Accuracy: 61.46% - Validation Loss: 0.6398
# Average Validation Accuracy: 64.19604700854701
# Training with LR=0.0001, WD=1e-06, Dropout=0.7
# Fold 1/3
# Epoch 1/10: - Training Accuracy: 54.15% - Training Loss: 0.6829 - Time Taken: 3.0099 seconds
#   - Validation Accuracy: 54.31% - Validation Loss: 0.6754
# Epoch 2/10: - Training Accuracy: 54.05% - Training Loss: 0.6776 - Time Taken: 3.0163 seconds
#   - Validation Accuracy: 54.55% - Validation Loss: 0.6649
# Epoch 3/10: - Training Accuracy: 58.07% - Training Loss: 0.6585 - Time Taken: 3.1005 seconds
#   - Validation Accuracy: 70.23% - Validation Loss: 0.6161
# Epoch 4/10: - Training Accuracy: 68.45% - Training Loss: 0.6119 - Time Taken: 3.0685 seconds
#   - Validation Accuracy: 72.80% - Validation Loss: 0.5765
# Epoch 5/10: - Training Accuracy: 63.39% - Training Loss: 0.6295 - Time Taken: 3.0184 seconds
#   - Validation Accuracy: 53.73% - Validation Loss: 0.6732
# Epoch 6/10: - Training Accuracy: 59.99% - Training Loss: 0.6446 - Time Taken: 3.0281 seconds
#   - Validation Accuracy: 56.09% - Validation Loss: 0.6580
# Epoch 7/10: - Training Accuracy: 63.52% - Training Loss: 0.6255 - Time Taken: 3.1158 seconds
#   - Validation Accuracy: 68.65% - Validation Loss: 0.6022
# Epoch 8/10: - Training Accuracy: 68.17% - Training Loss: 0.6051 - Time Taken: 3.0252 seconds
#   - Validation Accuracy: 68.53% - Validation Loss: 0.5964
# Epoch 9/10: - Training Accuracy: 69.40% - Training Loss: 0.5962 - Time Taken: 3.0288 seconds
#   - Validation Accuracy: 68.97% - Validation Loss: 0.5910
# Epoch 10/10: - Training Accuracy: 68.20% - Training Loss: 0.5967 - Time Taken: 3.0245 seconds
#   - Validation Accuracy: 68.85% - Validation Loss: 0.5857
# Fold 2/3
# Epoch 1/10: - Training Accuracy: 53.85% - Training Loss: 0.6829 - Time Taken: 3.1475 seconds
#   - Validation Accuracy: 54.27% - Validation Loss: 0.6753
# Epoch 2/10: - Training Accuracy: 54.93% - Training Loss: 0.6705 - Time Taken: 3.0360 seconds
#   - Validation Accuracy: 57.29% - Validation Loss: 0.6503
# Epoch 3/10: - Training Accuracy: 56.53% - Training Loss: 0.6721 - Time Taken: 3.0257 seconds
#   - Validation Accuracy: 54.53% - Validation Loss: 0.6801
# Epoch 4/10: - Training Accuracy: 55.50% - Training Loss: 0.6626 - Time Taken: 3.0651 seconds
#   - Validation Accuracy: 56.91% - Validation Loss: 0.6499
# Epoch 5/10: - Training Accuracy: 66.64% - Training Loss: 0.6285 - Time Taken: 3.1216 seconds
#   - Validation Accuracy: 67.73% - Validation Loss: 0.6334
# Epoch 6/10: - Training Accuracy: 69.76% - Training Loss: 0.6061 - Time Taken: 3.0445 seconds
#   - Validation Accuracy: 70.13% - Validation Loss: 0.5969
# Epoch 7/10: - Training Accuracy: 68.84% - Training Loss: 0.6014 - Time Taken: 3.0331 seconds
#   - Validation Accuracy: 59.74% - Validation Loss: 0.6547
# Epoch 8/10: - Training Accuracy: 68.30% - Training Loss: 0.6048 - Time Taken: 3.1171 seconds
#   - Validation Accuracy: 71.41% - Validation Loss: 0.5828
# Epoch 9/10: - Training Accuracy: 69.39% - Training Loss: 0.5968 - Time Taken: 3.0590 seconds
#   - Validation Accuracy: 69.25% - Validation Loss: 0.5843
# Epoch 10/10: - Training Accuracy: 69.52% - Training Loss: 0.5910 - Time Taken: 3.0330 seconds
#   - Validation Accuracy: 55.09% - Validation Loss: 0.6758
# Fold 3/3
# Epoch 1/10: - Training Accuracy: 53.44% - Training Loss: 0.6831 - Time Taken: 3.0307 seconds
#   - Validation Accuracy: 54.45% - Validation Loss: 0.6784
# Early stopping: Validation loss has not decreased for 3 epochs.
# Average Validation Accuracy: 62.652243589743605
# Best Hyperparameters: {'lr': 0.001, 'wd': 1e-06, 'dropout': 0.3}
# Best Validation Accuracy: 84.52667124542124

# %% [markdown]
# ### Best Hyperparameters: {'lr': 0.001, 'wd': 1e-06, 'dropout': 0.3}
# ### Best Validation Accuracy: 84.52667124542124
